# %% [markdown]
# # runs parcels on existing netcdf files
#
# relies on the files generated by `access_thredds` notebook as well as the `gapfilling` notebook (to get interpolated vector fields)

# %%
# %matplotlib inline

# %%
import math
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from parcels import FieldSet, ParticleSet, JITParticle, plotTrajectoriesFile
from parcels import AdvectionRK4
from datetime import timedelta, datetime

# %% [markdown]
# ### netcdf files
#
# the selected file must also have an interpolated version of it generated by `gapfilling`
#
# this is for running comparisons mostly

# %%
# 6 km res files
# category = "west_coast_6km_hourly"
# filename = "west_coast_6km_hourly_netcdfs/west_coast_6km_hourly_region0.nc"

# 2 km res files
category = "west_coast_2km_hourly"
filename = "west_coast_2km_hourly_netcdfs/west_coast_2km_hourly_region0.nc"

# 1 km res files
# category = "west_coast_1km_hourly"
# filename = ""

filename_interp = filename.split(".nc")[0] + "_interped.nc"

# %% [markdown]
# ## setup: open the file as xarray first
#
# load into xarray first so you actually have the time data, and don't have to deal with `deferred_load`
#
# `deferred_load` likes to make time data disappear

# %%
fs_xr = xr.open_dataset(filename)
fs_xr
# Out:
# <xarray.Dataset>
# Dimensions:                (lat: 186, lon: 249, nv: 2, time: 169, time_1: 1)
# Coordinates:
#   * lat                    (lat) float32 32.2278 32.24578 ... 35.53612 35.5541
#   * lon                    (lon) float32 -121.84389 -121.82306 ... -116.68008
#   * time                   (time) datetime64[ns] 2020-06-16T21:00:00 ... 2020-06-23T21:00:00
#     time_run               (time) datetime64[ns] ...
# Dimensions without coordinates: nv, time_1
# Data variables:
#     time_bnds              (time_1, nv) int32 ...
#     depth_bnds             (nv) float32 ...
#     wgs84                  int8 ...
#     processing_parameters  int8 ...
#     radial_metadata        int8 ...
#     depth                  float32 ...
#     time_offset            (time) datetime64[ns] ...
#     u                      (time, lat, lon) float32 ...
#     v                      (time, lat, lon) float32 ...
#     dopx                   (time, lat, lon) float32 ...
#     dopy                   (time, lat, lon) float32 ...
#     hdop                   (time, lat, lon) float32 ...
#     number_of_sites        (time, lat, lon) float32 ...
#     number_of_radials      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:               CF-1.4, ACDD-1.3
#     id:                        202007011900siohfruwlsrtvuswc2km
#     date_created:              2020-07-01T21:20:25Z
#     source:                    surface ocean velocity field from hf-radar
#     program:                   Integrated Ocean Observing System (IOOS)
#     title:                     Near-Real Time Surface Ocean Velocity, U.S. We...
#     summary:                   Surface ocean velocities estimated from HF-Rad...
#     instrument:                Earth Remote Sensing Instruments, Active Remot...
#     keywords:                  Earth Science, Oceans, Sea Surface, Coastal Pr...
#     geospatial_lat_min:        30.25
#     geospatial_lat_max:        49.99204
#     geospatial_lon_min:        -130.36
#     geospatial_lon_max:        -115.805565
#     processing_level:          Near real-time dataset with automated data acq...
#     history:                   2020-07-01T20:20:41Z hfrnet rtvMergeData: Savi...
#     references:                Terrill, E. et al., 2006. Data Management and ...
#     institution:               Coastal Observing Research and Development Cen...
#     creator_type:              group
#     creator_name:              HFRNet Administrators
#     creator_email:             hfrnet.administrators@sio.ucsd.edu
#     creator_url:               http://cordc.ucsd.edu/projects/mapping/
#     naming_authority:          edu.ucsd.cordc
#     standard_name_vocabulary:  CF Standard Name Table, Version 51
#     keywords_vocabulary:       Global Change Master Directory (GCMD) Keywords...
#     instrument_vocabulary:     Global Change Master Directory (GCMD) Keywords...
#     format_version:            1.1.00
#     product_version:           2.0.00
#     _CoordSysBuilder:          ucar.nc2.dataset.conv.CF1Convention
#     cdm_data_type:             GRID
#     featureType:               GRID
#     location:                  Proto fmrc:HFRADAR_US_West_Coast_2km_Resolutio...

# %%
fs_xr_interped = xr.open_dataset(filename_interp)
fs_xr_interped
# Out:
# <xarray.Dataset>
# Dimensions:                (lat: 186, lon: 249, nv: 2, time: 169, time_1: 1)
# Coordinates:
#   * lat                    (lat) float32 32.2278 32.24578 ... 35.53612 35.5541
#   * lon                    (lon) float32 -121.84389 -121.82306 ... -116.68008
#   * time                   (time) datetime64[ns] 2020-06-16T21:00:00 ... 2020-06-23T21:00:00
#     time_run               (time) datetime64[ns] ...
# Dimensions without coordinates: nv, time_1
# Data variables:
#     time_bnds              (time_1, nv) int32 ...
#     depth_bnds             (nv) float32 ...
#     wgs84                  int8 ...
#     processing_parameters  int8 ...
#     radial_metadata        int8 ...
#     depth                  float32 ...
#     time_offset            (time) datetime64[ns] ...
#     dopx                   (time, lat, lon) float32 ...
#     dopy                   (time, lat, lon) float32 ...
#     hdop                   (time, lat, lon) float32 ...
#     number_of_sites        (time, lat, lon) float32 ...
#     number_of_radials      (time, lat, lon) float32 ...
#     u                      (time, lat, lon) float64 ...
#     v                      (time, lat, lon) float64 ...
# Attributes:
#     Conventions:               CF-1.4, ACDD-1.3
#     id:                        202007011900siohfruwlsrtvuswc2km
#     date_created:              2020-07-01T21:20:25Z
#     source:                    surface ocean velocity field from hf-radar
#     program:                   Integrated Ocean Observing System (IOOS)
#     title:                     Near-Real Time Surface Ocean Velocity, U.S. We...
#     summary:                   Surface ocean velocities estimated from HF-Rad...
#     instrument:                Earth Remote Sensing Instruments, Active Remot...
#     keywords:                  Earth Science, Oceans, Sea Surface, Coastal Pr...
#     geospatial_lat_min:        30.25
#     geospatial_lat_max:        49.99204
#     geospatial_lon_min:        -130.36
#     geospatial_lon_max:        -115.805565
#     processing_level:          Near real-time dataset with automated data acq...
#     history:                   2020-07-01T20:20:41Z hfrnet rtvMergeData: Savi...
#     references:                Terrill, E. et al., 2006. Data Management and ...
#     institution:               Coastal Observing Research and Development Cen...
#     creator_type:              group
#     creator_name:              HFRNet Administrators
#     creator_email:             hfrnet.administrators@sio.ucsd.edu
#     creator_url:               http://cordc.ucsd.edu/projects/mapping/
#     naming_authority:          edu.ucsd.cordc
#     standard_name_vocabulary:  CF Standard Name Table, Version 51
#     keywords_vocabulary:       Global Change Master Directory (GCMD) Keywords...
#     instrument_vocabulary:     Global Change Master Directory (GCMD) Keywords...
#     format_version:            1.1.00
#     product_version:           2.0.00
#     _CoordSysBuilder:          ucar.nc2.dataset.conv.CF1Convention
#     cdm_data_type:             GRID
#     featureType:               GRID
#     location:                  Proto fmrc:HFRADAR_US_West_Coast_2km_Resolutio...

# %%
lat_range = (float(fs_xr["lat"].min()), float(fs_xr["lat"].max()))
lon_range = (float(fs_xr["lon"].min()), float(fs_xr["lon"].max()))
print(lat_range, lon_range)
# Out:
# (32.22779846191406, 35.554100036621094) (-121.84388732910156, -116.6800765991211)

# %%
fs = FieldSet.from_xarray_dataset(fs_xr, dict(U="u",V="v"), dict(lat="lat",lon="lon",time="time"))
fs_interped = FieldSet.from_xarray_dataset(fs_xr_interped, dict(U="u",V="v"), dict(lat="lat",lon="lon",time="time"))

# needed in case you want to generate the regions again without restarting this notebook
fs_xr.close()
fs_xr_interped.close()
# Out:
# WARNING: Casting depth data to np.float32
# WARNING: Casting field data to np.float32

# %%
for i in range(169):
    a = fs_xr.isel(time=i)["number_of_sites"].sum().values
    print(f"time {i}: {a}")
# Out:
# time 0: 21520.0
# time 1: 22331.0
# time 2: 19797.0
# time 3: 19520.0
# time 4: 20106.0
# time 5: 20832.0
# time 6: 21617.0
# time 7: 22772.0
# time 8: 23021.0
# time 9: 22290.0
# time 10: 21473.0
# time 11: 20904.0
# time 12: 20779.0
# time 13: 21009.0
# time 14: 20842.0
# time 15: 20639.0
# time 16: 20823.0
# time 17: 21167.0
# time 18: 20743.0
# time 19: 21376.0
# time 20: 21111.0
# time 21: 21254.0
# time 22: 21469.0
# time 23: 21477.0
# time 24: 21441.0
# time 25: 20762.0
# time 26: 21000.0
# time 27: 18524.0
# time 28: 20629.0
# time 29: 20731.0
# time 30: 20663.0
# time 31: 20469.0
# time 32: 20070.0
# time 33: 19640.0
# time 34: 19386.0
# time 35: 20771.0
# time 36: 20067.0
# time 37: 17675.0
# time 38: 17267.0
# time 39: 17845.0
# time 40: 18018.0
# time 41: 17089.0
# time 42: 17559.0
# time 43: 17234.0
# time 44: 17350.0
# time 45: 17646.0
# time 46: 17464.0
# time 47: 20971.0
# time 48: 21336.0
# time 49: 21462.0
# time 50: 21419.0
# time 51: 21403.0
# time 52: 21020.0
# time 53: 21098.0
# time 54: 20992.0
# time 55: 20690.0
# time 56: 20531.0
# time 57: 19454.0
# time 58: 17684.0
# time 59: 19510.0
# time 60: 19643.0
# time 61: 19476.0
# time 62: 17971.0
# time 63: 18283.0
# time 64: 18125.0
# time 65: 19030.0
# time 66: 19445.0
# time 67: 18440.0
# time 68: 18981.0
# time 69: 19347.0
# time 70: 19810.0
# time 71: 21330.0
# time 72: 22139.0
# time 73: 22184.0
# time 74: 22285.0
# time 75: 22040.0
# time 76: 22202.0
# time 77: 22339.0
# time 78: 21840.0
# time 79: 21663.0
# time 80: 20356.0
# time 81: 20682.0
# time 82: 20817.0
# time 83: 20973.0
# time 84: 20608.0
# time 85: 20520.0
# time 86: 19868.0
# time 87: 19022.0
# time 88: 18247.0
# time 89: 15992.0
# time 90: 15732.0
# time 91: 15886.0
# time 92: 18576.0
# time 93: 18931.0
# time 94: 18671.0
# time 95: 15733.0
# time 96: 15701.0
# time 97: 16019.0
# time 98: 18264.0
# time 99: 17474.0
# time 100: 17938.0
# time 101: 18396.0
# time 102: 18388.0
# time 103: 17918.0
# time 104: 18242.0
# time 105: 17828.0
# time 106: 17649.0
# time 107: 17126.0
# time 108: 17167.0
# time 109: 17261.0
# time 110: 16968.0
# time 111: 16825.0
# time 112: 16243.0
# time 113: 16171.0
# time 114: 16675.0
# time 115: 19935.0
# time 116: 20622.0
# time 117: 20586.0
# time 118: 20694.0
# time 119: 20997.0
# time 120: 21164.0
# time 121: 21564.0
# time 122: 21740.0
# time 123: 21485.0
# time 124: 21171.0
# time 125: 22092.0
# time 126: 21562.0
# time 127: 21556.0
# time 128: 21543.0
# time 129: 21887.0
# time 130: 21820.0
# time 131: 21529.0
# time 132: 21382.0
# time 133: 20774.0
# time 134: 19976.0
# time 135: 20460.0
# time 136: 20055.0
# time 137: 19692.0
# time 138: 20310.0
# time 139: 20372.0
# time 140: 18396.0
# time 141: 21699.0
# time 142: 18929.0
# time 143: 21215.0
# time 144: 22088.0
# time 145: 20051.0
# time 146: 20052.0
# time 147: 19922.0
# time 148: 20883.0
# time 149: 20458.0
# time 150: 20015.0
# time 151: 20524.0
# time 152: 20388.0
# time 153: 19655.0
# time 154: 20698.0
# time 155: 20445.0
# time 156: 21154.0
# time 157: 21054.0
# time 158: 20999.0
# time 159: 20536.0
# time 160: 19915.0
# time 161: 19264.0
# time 162: 19351.0
# time 163: 18349.0
# time 164: 17208.0
# time 165: 18147.0
# time 166: 17896.0
# time 167: 20751.0
# time 168: 22380.0

# %%
fs_radarnum = FieldSet.from_xarray_dataset(fs_xr, dict(U="number_of_sites",V="number_of_radials"), dict(lat="lat",lon="lon",time="time"))
fs_radarnum.U.show(vmax=8)
fs_radarnum.U.show(show_time=fs.U.grid.time[8], vmax=8)
# Out:
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
fs.U.show()
fs_interped.U.show()

# %%
time_range = fs.gridset.dimrange("time")
time_range
# Out:
# (0.0, 604800.0)

# %% [markdown]
# ## Animated gif stuff
#
# because it looks cool

# %%
# animation man very cool
# reference tutorial_Agulhasparticles
# needs ErrorCode for particle recovery
from parcels import ErrorCode

num_lon = 10
num_lat = 15
max_v = 1.1

interp = "linear"
fs.U.interp_method = interp
fs.V.interp_method = interp

def DeleteParticle(particle, fieldset, time):
    particle.delete()
    
def exec_save_pset(pset, path, runtime, dt, maxv):
    pset.show(savefile=path, field='vector', land=True, vmax=maxv)
    
    pset.execute(AdvectionRK4,
                 runtime=timedelta(seconds=runtime),
                 dt=timedelta(seconds=dt),
                 recovery={ErrorCode.ErrorOutOfBounds: DeleteParticle})

# %%
p_lons, p_lats = np.meshgrid(np.linspace(lon_range[0], lon_range[1], num_lon), np.linspace(lat_range[0], lat_range[1], num_lat))
pset_grid = ParticleSet(fieldset=fs, pclass=JITParticle, lon=p_lons, lat=p_lats, time=time_range[0])
pset_grid_interped = ParticleSet(fieldset=fs_interped, pclass=JITParticle, lon=p_lons, lat=p_lats, time=time_range[0])

# %%
pset_grid.show(field="vector", vmax=max_v)
pset_grid_interped.show(field="vector", vmax=max_v)
# Out:
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:187: RuntimeWarning: invalid value encountered in true_divide
#   u = np.where(speed > 0., data[0]/speed, 0)
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:188: RuntimeWarning: invalid value encountered in true_divide
#   v = np.where(speed > 0., data[1]/speed, 0)

# %%
import os

snapshot_interval = 3600 * 8 # seconds
p_dt = 300 # seconds
snapshot_num = math.floor((time_range[1] - time_range[0]) / snapshot_interval)
last_interval = time_range[1] - snapshot_num * snapshot_interval
if last_interval == 0:
    print(f"Snapshots to save: {snapshot_num + 1}")
else:
    print(f"Snapshots to save: {snapshot_num + 2}")
current_time = str(datetime.now().time())
save_dir = f"snapshots_{category}/"
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
    print(f"created directory {save_dir}")
# Out:
# Snapshots to save: 22
# created directory snapshots_west_coast_2km_hourly/

# %%
for i in range(snapshot_num):
    exec_save_pset(pset_grid, save_dir+"particles"+str(i).zfill(3), snapshot_interval, p_dt, max_v)
    exec_save_pset(pset_grid_interped, save_dir+"particles_interped"+str(i).zfill(3), snapshot_interval, p_dt, max_v)

# save the second-to-last frame
pset_grid.show(savefile=save_dir+"particles"+str(snapshot_num).zfill(3), field='vector', vmax=max_v)
pset_grid_interped.show(savefile=save_dir+"particles_interped"+str(snapshot_num).zfill(3), field='vector', vmax=max_v)

# run the last interval (the remainder) if needed
if last_interval != 0:
    exec_save_pset(pset_grid, save_dir+"particles"+str(snapshot_num + 1).zfill(3), last_interval, p_dt, max_v)
    exec_save_pset(pset_grid_interped, save_dir+"particles_interped"+str(snapshot_num + 1).zfill(3), last_interval, p_dt, max_v)

print("done")
# Out:
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles000.png
# INFO: Compiled JITParticleAdvectionRK4 ==> /var/folders/mb/hd5ymr3137g2g0chv_x_tvb40000gq/T/parcels-503/01661863a83bf764d869c6bed4b6179a_0.so
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:187: RuntimeWarning: invalid value encountered in true_divide
#   u = np.where(speed > 0., data[0]/speed, 0)
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:188: RuntimeWarning: invalid value encountered in true_divide
#   v = np.where(speed > 0., data[1]/speed, 0)
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped000.png
# INFO: Compiled JITParticleAdvectionRK4 ==> /var/folders/mb/hd5ymr3137g2g0chv_x_tvb40000gq/T/parcels-503/4afdda4fb9f2ac7db4a321aa5c4e39b0_0.so
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:307: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/cartopy/mpl/gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:187: RuntimeWarning: invalid value encountered in true_divide
#   u = np.where(speed > 0., data[0]/speed, 0)
# /Users/jerry/opt/anaconda3/envs/py3_parcels/lib/python3.6/site-packages/parcels/plotting.py:188: RuntimeWarning: invalid value encountered in true_divide
#   v = np.where(speed > 0., data[1]/speed, 0)
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles001.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped001.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles002.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped002.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles003.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped003.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles004.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped004.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles005.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped005.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles006.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped006.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles007.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped007.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles008.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped008.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles009.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped009.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles010.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped010.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles011.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped011.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles012.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped012.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles013.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped013.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles014.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped014.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles015.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped015.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles016.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped016.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles017.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped017.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles018.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped018.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles019.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped019.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles020.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped020.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles021.png
# INFO: Plot saved to snapshots_west_coast_2km_hourly/particles_interped021.png
# done
